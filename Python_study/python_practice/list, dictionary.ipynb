# %%
import random
print(random.random())              #0.0부터 1.0보다 작은 실수 난수
print(random.randint(1,100))        #1부터 100 사이의 정수 난수
print(random.choice('abcdefghij'))  #하나의 랜덤한 항목

items=[1,2,3,4,5,6,7]
random.shuffle(items)
print(items)
# Out:
# 0.9075828044760036
# 23
# f
# [4, 1, 3, 7, 6, 2, 5]

# %%
#list
numbers = [7,12,33,777]
print(numbers)
print(numbers[0])

heroes =[]
heroes.append("아이언맨")
heroes.append('토르')
print(heroes)

list1 = [10,20,"슈퍼맨"]
print(list1)

letters = ['A','B','C','D','E','F','G']
print(letters[0:3])
print(letters[:3])
print(letters[3:])
print(letters[:])

heroes = ['아이언맨','토르','헐크','스칼렛 위치']
heroes[1]='닥터 스트레인지'
print(heroes)


heroes.append('스파이더맨')
print(heroes)
heroes.insert(1,'배트맨')    #[1] 삽입.
print(heroes)

heroes.remove('스칼렛 위치')
print(heroes)

if '슈퍼맨' in heroes:
    heroes.remove('슈퍼맨')  #항목에 없을 경우 오류가 뜨니까 if, in 사용.
    
del heroes[0]  #0번째 항목 삭제
print(heroes)

last_hero = heroes.pop()    #리스트에서 마지막 항목 "삭제"하여 우리에게.
print(last_hero)            #원래 리스트 안에는 존재X

#리스트 탐색
print(heroes)
print(heroes.index("헐크"))

if '헐크' in heroes:       #리스트 안에 존재하지 않으면 오류 발생하니까 if 사용.
    print(heroes.index("헐크"))
    
heroes=['아이언맨','토르','헐크','스칼렛 위치']
for hero in heroes:
    print(hero)
    
#리스트 정렬
heroes = ['아이언맨','토르','헐크','스칼렛 위치']
print(heroes)
heroes.sort()
print(heroes)

numbers=[9,8,4,5,1,2,7,3,6]
print(numbers)
numbers.sort()     #원래의 리스트 변경.
print(numbers)

numbers=[9,8,4,5,1,2,7,3,6]
new_list = sorted(numbers)    #정렬된 새로운 리스트 생성. 기존 리스트 유지.
print(numbers)
print(new_list)

numbers=[9,8,4,5,1,2,7,3,6]
new_list = sorted(numbers,reverse=True)   #순서 반대로 정렬.
print(numbers)
print(new_list)
# Out:
# [7, 12, 33, 777]
# 7
# ['아이언맨', '토르']
# [10, 20, '슈퍼맨']
# ['A', 'B', 'C']
# ['A', 'B', 'C']
# ['D', 'E', 'F', 'G']
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']
# ['아이언맨', '닥터 스트레인지', '헐크', '스칼렛 위치']
# ['아이언맨', '닥터 스트레인지', '헐크', '스칼렛 위치', '스파이더맨']
# ['아이언맨', '배트맨', '닥터 스트레인지', '헐크', '스칼렛 위치', '스파이더맨']
# ['아이언맨', '배트맨', '닥터 스트레인지', '헐크', '스파이더맨']
# ['배트맨', '닥터 스트레인지', '헐크', '스파이더맨']
# 스파이더맨
# ['배트맨', '닥터 스트레인지', '헐크']
# 2
# 2
# 아이언맨
# 토르
# 헐크
# 스칼렛 위치
# ['아이언맨', '토르', '헐크', '스칼렛 위치']
# ['스칼렛 위치', '아이언맨', '토르', '헐크']
# [9, 8, 4, 5, 1, 2, 7, 3, 6]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [9, 8, 4, 5, 1, 2, 7, 3, 6]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [9, 8, 4, 5, 1, 2, 7, 3, 6]
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
#리스트(list)

slist = ['영어','수학','사회','과학']
print(slist)

list1 = [1,2,3,4]
print(list1)

list=[]
list.append(1)
list.append(2)
list.append(3)
list.append(6)
print(list)

#리스트의 첫번째 항목 : list[0]
print(list[0])
print(slist[0])


friend_list = []
friend = input("친구의 이름을 입력하시오: ")
friend_list.append(friend)
friend = input("친구의 이름을 입력하시오: ")
friend_list.append(friend)
friend = input("친구의 이름을 입력하시오: ")
friend_list.append(friend)
friend = input("친구의 이름을 입력하시오: ")
friend_list.append(friend)
print(friend_list)

# %%
#리스트에 저장된 생상으로 원 그리기
import turtle
t = turtle.Turtle()
t.shape("turtle")

color_list = ["yellow", "red", "blue", "green"]

t.fillcolor(color_list[0])
t.begin_fill()
t.circle(100)
t.end_fill()

t.fd(50)
t.fillcolor(color_list[1])
t.begin_fill()
t.circle(100)
t.end_fill()

t.fd(50)
t.fillcolor(color_list[2])
t.begin_fill()
t.circle(100)
t.end_fill()

t.fd(50)
t.fillcolor(color_list[3])
t.begin_fill()
t.circle(100)
t.end_fill()

s='python'
print(s)

print(s[0:2])
print(s[1:2])

# %%
#딕셔너리(dictionary)
#키(key) -> 값(value)

phone_book = {}
phone_book["홍길동"] = "010-1234-5677"
print(phone_book)

phone_book1 = {"홍길동":"010-3234-1253"}
print(phone_book1)

phone_book["강감찬"]="010-1234-5678"
phone_book["이순신"]="010-1234-5678"
print(phone_book)

print(phone_book["강감찬"])
print(phone_book.keys())
print(phone_book.values())

dict={"name":'홍길동','Age':7,'class':'초급'}
print(dict['name'])
print(dict["Age"])

for key in sorted(phone_book.keys()):
    print(key, phone_book[key])
    
del phone_book["홍길동"]
print(phone_book)

phone_book.clear()
print(phone_book)

items = {"커피음료":7, "펜":3, "종이컵":2, "우유":1, "콜라":4, "책":5}
item = input('물건의 이름을 입력하시오: ');
print(items[item])

english_dict = {}

english_dict['one'] = '하나'
english_dict['two'] = '둘'
english_dict['three'] = '셋'

word = input("단어를 입력하시오: ");
print(english_dict[word])
# Out:
# {'홍길동': '010-1234-5677'}
# {'홍길동': '010-3234-1253'}
# {'홍길동': '010-1234-5677', '강감찬': '010-1234-5678', '이순신': '010-1234-5678'}
# 010-1234-5678
# dict_keys(['홍길동', '강감찬', '이순신'])
# dict_values(['010-1234-5677', '010-1234-5678', '010-1234-5678'])
# 홍길동
# 7
# 강감찬 010-1234-5678
# 이순신 010-1234-5678
# 홍길동 010-1234-5677
# {'강감찬': '010-1234-5678', '이순신': '010-1234-5678'}
# {}
# 물건의 이름을 입력하시오: 펜
# 3
# 단어를 입력하시오: one
# 하나
